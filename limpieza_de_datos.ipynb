# %%
import pandas as pd

df = pd.read_csv("SalesJan2009.csv")
df
# Out:
#     Transaction_date   Product Price Payment_Type               Name  \
# 0        1/2/09 6:17  Product1  1200   Mastercard           carolina
# 1        1/2/09 4:53  Product1  1200         Visa             Betina
# 2       1/2/09 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3       1/3/09 14:44  Product1  1200         Visa              Gouya
# 4       1/4/09 12:56  Product2  3600         Visa            Gerd W
# ..               ...       ...   ...          ...                ...
# 993    1/22/09 14:25  Product1  1200         Visa         Hans-Joerg
# 994     1/28/09 5:36  Product2  3600         Visa         Christiane
# 995      1/1/09 4:24  Product3  7500         Amex             Pamela
# 996     1/8/09 11:55  Product1  1200       Diners              julie
# 997    1/12/09 21:30  Product1  1200         Visa             Julia
#
#                              City             State         Country  \
# 0                        Basildon           England  United Kingdom
# ...

# %% [markdown]
# ##Analisis en la columna product

# %%
df["Product"].unique()
# Out:
# array(['Product1', 'Product2', 'Product3', 'Product3 '], dtype=object)

# %%
df.drop(df[df['Product'] == 'Product3 '].index, inplace=True)

# %%
df["Product"].unique()
# Out:
# array(['Product1', 'Product2', 'Product3'], dtype=object)

# %% [markdown]
# ##Analisis en la columna Price

# %%
df["Price"].unique()
# Out:
# array(['1200', '3600', '2100', '7500', '800', '1250', '250', '1800',
#        '13,000'], dtype=object)

# %%
df.drop(df[df['Price'] == "13,000"].index, inplace=True)

# %%
df["Price"].unique()
# Out:
# array(['1200', '3600', '2100', '7500', '800', '1250', '250', '1800'],
#       dtype=object)

# %% [markdown]
# ##analizar si hay elementos vacios

# %%
df.shape
# Out:
# (996, 12)

# %%
df.dropna()
# Out:
#     Transaction_date   Product Price Payment_Type               Name  \
# 0        1/2/09 6:17  Product1  1200   Mastercard           carolina
# 1        1/2/09 4:53  Product1  1200         Visa             Betina
# 2       1/2/09 13:08  Product1  1200   Mastercard  Federica e Andrea
# 3       1/3/09 14:44  Product1  1200         Visa              Gouya
# 4       1/4/09 12:56  Product2  3600         Visa            Gerd W
# ..               ...       ...   ...          ...                ...
# 993    1/22/09 14:25  Product1  1200         Visa         Hans-Joerg
# 994     1/28/09 5:36  Product2  3600         Visa         Christiane
# 995      1/1/09 4:24  Product3  7500         Amex             Pamela
# 996     1/8/09 11:55  Product1  1200       Diners              julie
# 997    1/12/09 21:30  Product1  1200         Visa             Julia
#
#                              City             State         Country  \
# 0                        Basildon           England  United Kingdom
# ...

# %%
df.shape
# Out:
# (996, 12)

# %%
df["Payment_Type"].unique()
# Out:
# array(['Mastercard', 'Visa', 'Diners', 'Amex'], dtype=object)

# %%
df["Transaction_date"].unique()
# Out:
# array(['1/2/09 6:17', '1/2/09 4:53', '1/2/09 13:08', '1/3/09 14:44',
#        '1/4/09 12:56', '1/4/09 13:19', '1/4/09 20:11', '1/2/09 20:09',
#        '1/4/09 13:17', '1/4/09 14:11', '1/5/09 2:42', '1/5/09 5:39',
#        '1/2/09 9:16', '1/5/09 10:08', '1/2/09 14:18', '1/4/09 1:05',
#        '1/5/09 11:37', '1/6/09 5:02', '1/6/09 7:45', '1/2/09 7:35',
#        '1/6/09 12:56', '1/1/09 11:05', '1/5/09 4:10', '1/6/09 7:18',
#        '1/2/09 1:11', '1/1/09 2:24', '1/7/09 8:08', '1/2/09 2:57',
#        '1/1/09 20:21', '1/8/09 0:42', '1/8/09 3:56', '1/8/09 3:16',
#        '1/8/09 1:59', '1/3/09 9:03', '1/5/09 13:17', '1/6/09 7:46',
#        '1/5/09 20:00', '1/8/09 16:24', '1/9/09 6:39', '1/6/09 22:19',
#        '1/6/09 23:00', '1/7/09 7:44', '1/3/09 13:24', '1/7/09 15:12',
#        '1/7/09 20:15', '1/3/09 10:11', '1/9/09 15:58', '1/3/09 13:11',
#        '1/10/09 12:57', '1/10/09 14:43', '1/10/09 12:05', '1/6/09 1:20',
# ...

# %%
df["Name"].unique()
# Out:
# array(['carolina', 'Betina', 'Federica e Andrea', 'Gouya', 'Gerd W ',
#        'LAURENCE', 'Fleur', 'adam', 'Renee Elisabeth', 'Aidan', 'Stacy',
#        'Heidi', 'Sean ', 'Georgia', 'Richard', 'Leanne', 'Janet',
#        'barbara', 'Sabine', 'Hani', 'Jeremy', 'Janis', 'Nicola', 'asuman',
#        'Lena', 'Lisa', 'Bryan Kerrene', 'chris', 'Maxine', 'Family',
#        'Katherine', 'Linda', 'SYLVIA', 'Sheila', 'Stephanie', 'Kelly',
#        'James', 'jennifer', 'Anneli', 'Ritz', 'Sylvia', 'Marie',
#        'Mehmet Fatih', 'Anabela', 'Nicole', 'Christiane ', 'Sari',
#        'simone', 'Vanessa', 'Anupam', 'Karina', 'Frank', 'Angela',
#        'Darren', 'Nikki', 'Anushka', 'June ', 'Baybars', 'Bonnie',
#        'Cindy ', 'chrissy', 'Tamar', 'Deirdre', 'Bernadett', 'Dottie',
#        'Stefan', 'Gina', 'Lynne', 'Tammy', 'Kim', 'Bruce', 'Rosa Maria',
#        'Lydia', 'Eric', 'AnaPaula', 'Robin', 'Gitte', 'Dr. Claudia',
# ...

# %%
df["City"].unique()
# Out:
# array(['Basildon', 'Parkville                   ',
#        'Astoria                     ', 'Echuca',
#        'Cahaba Heights              ', 'Mickleton                   ',
#        'Peoria                      ', 'Martin                      ',
#        'Tel Aviv', 'Chatou', 'New York                    ', 'Eindhoven',
#        'Shavano Park                ', 'Eagle                       ',
#        'Riverside                   ', 'Julianstown', 'Ottawa',
#        'Hyderabad', 'London', 'Salt Lake City              ',
#        'Manchester', 'Ballynora', 'Roodepoort',
#        'Chula Vista                 ', 'Kuopio',
#        'Sugar Land                  ', 'Morton                      ',
#        'Los Gatos                   ', 'Miami                       ',
#        'Vesenaz', 'Brooklyn                    ', 'Badhoevedorp',
#        'Reston                      ', 'Burpengary',
#        'Phoenix                     ', 'Houston                     ',
# ...

# %% [markdown]
# Al haber muchos espacios vacios lo limpiamos

# %%
df['City'] = df['City'].str.strip()

# %%
df["City"].unique()
# Out:
# array(['Basildon', 'Parkville', 'Astoria', 'Echuca', 'Cahaba Heights',
#        'Mickleton', 'Peoria', 'Martin', 'Tel Aviv', 'Chatou', 'New York',
#        'Eindhoven', 'Shavano Park', 'Eagle', 'Riverside', 'Julianstown',
#        'Ottawa', 'Hyderabad', 'London', 'Salt Lake City', 'Manchester',
#        'Ballynora', 'Roodepoort', 'Chula Vista', 'Kuopio', 'Sugar Land',
#        'Morton', 'Los Gatos', 'Miami', 'Vesenaz', 'Brooklyn',
#        'Badhoevedorp', 'Reston', 'Burpengary', 'Phoenix', 'Houston',
#        'Pittsfield', 'Ball Ground', 'Helsingor', 'Flossmoor',
#        'Delray Beach', 'Newbury', 'Kobenhavn', 'Sandy Springs',
#        'Kinsaley', 'Fort Lauderdale', 'Melbourne', 'Ankeny', 'Pittsboro',
#        'New Rochelle', 'Gold Coast', 'Brussels',
#        'Maple Ridge District Municipality', 'Beachwood', 'Prince Albert',
#        'Saltsjobaden', 'Kemble', 'W Lebanon', 'Headley', 'Lausanne',
#        'Southampton', 'Woodsboro', 'Stavanger', 'Red Deer', 'Memphis',
# ...

# %%
df["State"].unique()
# Out:
# array(['England', 'MO', 'OR', 'Victoria', 'AL', 'NJ', 'IL', 'TN',
#        'Tel Aviv', 'Ile-de-France', 'NY', 'Noord-Brabant', 'TX', 'ID',
#        'Meath', 'Ontario', 'Andhra Pradesh', 'UT', 'Cork', 'Gauteng',
#        'CA', 'Ita-Suomen Laani', 'FL', 'Geneve', 'Noord-Holland', 'VA',
#        'Queensland', 'AZ', 'VT', 'GA', 'Frederiksborg', 'Kobenhavn',
#        'Dublin', 'IA', 'NC', 'Brussels (Bruxelles)', 'British Columbia',
#        'OH', 'Saskatchewan', 'Stockholm', 'NH', 'Vaud', 'MD', 'Rogaland',
#        'Alberta', 'Luxembourg', 'Northern Ireland', 'Lombardy', 'Oslo',
#        'Michigan', 'Nordrhein-Westfalen', 'Storstrom', 'HI', 'Chisinau',
#        'Murcia', 'Dubayy', 'CO', 'Al Manamah', 'Upper Normandy', 'KY',
#        'Groningen', 'Quebec', 'Istanbul', 'WA', 'Zuid-Holland',
#        'Kilkenny', 'Schwyz', 'Hessen', nan, 'AR', 'Northwest Territories',
#        'MN', 'Manitoba', 'DC', 'Lower Saxony', 'Basel-Country', 'MI',
# ...

# %%
df["Country"].unique()
# Out:
# array(['United Kingdom', 'United States', 'Australia', 'Israel', 'France',
#        'Netherlands', 'Ireland', 'Canada', 'India', 'South Africa',
#        'Finland', 'Switzerland', 'Denmark', 'Belgium', 'Sweden', 'Norway',
#        'Luxembourg', 'Italy', 'Germany', 'Moldova', 'Spain',
#        'United Arab Emirates', 'Bahrain', 'Turkey', 'Kuwait', 'Malta',
#        'Hungary', 'Austria', 'Jersey', 'Malaysia', 'Iceland',
#        'South Korea', 'Brazil', 'New Zealand', 'Russia', 'Monaco',
#        'Hong Kong', 'Thailand', 'Bulgaria', 'Latvia', 'Poland',
#        'Philippines', 'Argentina', 'The Bahamas', 'Japan',
#        'Czech Republic', 'Cayman Isls', 'Ukraine', 'Dominican Republic',
#        'China', 'Greece', 'Costa Rica', 'Bermuda', 'Romania', 'Guatemala',
#        'Mauritius'], dtype=object)

# %%
df["Account_Created"].unique()
# Out:
# array(['1/2/09 6:00', '1/2/09 4:42', '1/1/09 16:21', '9/25/05 21:13',
#        '11/15/08 15:47', '9/24/08 15:19', '1/3/09 9:38', '1/2/09 17:43',
#        '1/4/09 13:03', '6/3/08 4:22', '1/5/09 2:23', '1/5/09 4:55',
#        '1/2/09 8:32', '11/11/08 15:53', '12/9/08 12:07', '1/4/09 0:00',
#        '1/5/09 9:35', '1/6/09 2:41', '1/6/09 7:00', '12/30/08 5:44',
#        '1/6/09 10:58', '12/10/07 12:37', '1/5/09 2:33', '1/6/09 7:07',
#        '12/31/08 2:48', '1/1/09 1:56', '1/7/09 7:39', '1/3/08 7:23',
#        '10/24/08 6:48', '1/8/09 0:28', '1/8/09 3:33', '1/8/09 3:06',
#        '11/28/07 11:56', '1/3/09 8:47', '1/5/09 12:45', '1/6/09 7:30',
#        '12/10/08 19:53', '1/8/09 15:57', '1/9/09 5:09', '1/6/09 12:00',
#        '1/7/09 5:35', '1/3/09 12:47', '1/5/09 19:55', '1/7/09 17:17',
#        '1/3/09 9:27', '1/9/09 14:53', '10/31/08 0:31', '2/7/07 20:16',
#        '1/9/09 11:38', '7/1/08 12:53', '1/2/09 17:51', '1/7/09 9:04',
# ...

# %%
df["Last_Login"].unique()
# Out:
# array(['1/2/09 6:08', '1/2/09 7:49', '1/3/09 12:32', '1/3/09 14:22',
#        '1/4/09 12:45', '1/4/09 13:04', '1/4/09 19:45', '1/4/09 20:01',
#        '1/4/09 22:10', '1/5/09 1:17', '1/5/09 4:59', '1/5/09 8:15',
#        '1/5/09 9:05', '1/5/09 10:05', '1/5/09 11:01', '1/5/09 13:36',
#        '1/5/09 19:24', '1/6/09 7:52', '1/6/09 9:17', '1/6/09 10:52',
#        '1/6/09 13:31', '1/7/09 1:52', '1/7/09 5:13', '1/7/09 7:08',
#        '1/7/09 10:20', '1/7/09 10:52', '1/7/09 12:38', '1/7/09 13:14',
#        '1/7/09 20:49', '1/8/09 3:39', '1/8/09 6:19', '1/8/09 6:34',
#        '1/8/09 7:20', '1/8/09 10:38', '1/8/09 11:45', '1/8/09 12:40',
#        '1/8/09 17:58', '1/8/09 18:30', '1/9/09 7:11', '1/9/09 10:05',
#        '1/9/09 10:52', '1/9/09 11:14', '1/9/09 16:03', '1/9/09 20:02',
#        '1/10/09 9:46', '1/10/09 13:16', '1/10/09 13:24', '1/10/09 14:09',
#        '1/10/09 14:37', '1/10/09 16:33', '1/10/09 18:27', '1/10/09 19:41',
# ...

# %%
df["Latitude"].unique()
# Out:
# array([ 51.5      ,  39.195    ,  46.18806  , -36.1333333,  33.52056  ,
#         39.79     ,  40.69361  ,  36.34333  ,  32.0666667,  48.8833333,
#         40.71417  ,  51.45     ,  29.42389  ,  43.69556  ,  40.03222  ,
#         53.6772222,  45.4166667,  17.3833333,  51.52721  ,  40.76083  ,
#         53.5      ,  51.8630556, -26.1666667,  32.64     ,  62.9      ,
#         29.61944  ,  40.61278  ,  37.22667  ,  25.77389  ,  46.2333333,
#         40.65     ,  52.3333333,  38.96861  , -27.1666667,  33.44833  ,
#         29.76306  ,  43.77222  ,  34.33806  ,  56.0333333,  41.54278  ,
#         26.46111  ,  51.4      ,  55.6666667,  33.92417  ,  53.4247222,
#         26.12194  , -37.8166667,  41.72972  ,  35.72     ,  40.91139  ,
#        -28.       ,  50.8333333,  49.25     ,  41.46444  ,  53.2      ,
#         59.2833333,  51.6766667,  43.64917  ,  51.1166667,  46.5333333,
#         50.9      ,  39.53306  ,  58.9666667,  52.2666667,  35.14944  ,
# ...

# %%
df["Longitude"].unique()
# Out:
# array([-1.11666670e+00, -9.46819400e+01, -1.23830000e+02,  1.44750000e+02,
#        -8.68025000e+01, -7.52380600e+01, -8.95888900e+01, -8.88502800e+01,
#         3.47666667e+01,  2.15000000e+00, -7.40063900e+01,  5.46666670e+00,
#        -9.84933300e+01, -1.16353060e+02, -7.49577800e+01, -6.31916670e+00,
#        -7.57000000e+01,  7.84666667e+01,  1.45590000e-01, -1.11890280e+02,
#        -2.21666670e+00, -8.58000000e+00,  2.78666667e+01, -1.17083330e+02,
#         2.76833333e+01, -9.56347200e+01, -8.94591700e+01, -1.21973610e+02,
#        -8.01938900e+01,  6.20000000e+00, -7.39500000e+01,  4.78333330e+00,
#        -7.73413900e+01,  1.52950000e+02, -1.12073330e+02, -9.53630600e+01,
#        -7.28133300e+01, -8.43766700e+01,  1.26166667e+01, -8.76847200e+01,
#        -8.00730600e+01, -1.31666670e+00,  1.25833333e+01, -8.43786100e+01,
#        -6.17583330e+00, -8.01436100e+01,  1.44966667e+02, -9.36055600e+01,
# ...

# %%
df.to_csv("SalesJan2009Limp.csv")
